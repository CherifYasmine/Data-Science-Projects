# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os

# Importing Deep Learning Libraries

from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense,Input,Dropout,GlobalAveragePooling2D,Flatten,Conv2D,BatchNormalization,Activation,MaxPooling2D
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.optimizers import Adam,SGD,RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
picture_size = 48
folder_path = "C://Users/hp/Desktop/dataset/images/"

# %% [markdown]
# ## Display the Data

# %%
expression = 'disgust'

plt.figure(figsize= (12,12))
for i in range(1, 10, 1):
    plt.subplot(3,3,i)
    img = load_img(folder_path+"train/"+expression+"/"+
                  os.listdir(folder_path + "train/" + expression)[i], target_size=(picture_size, picture_size))
    plt.imshow(img)   
plt.show()

# %% [markdown]
# ## Make Training and Validation Data

# %%
batch_size  = 128

datagen_train  = ImageDataGenerator()
datagen_val = ImageDataGenerator()

train_set = datagen_train.flow_from_directory(folder_path+"train",
                                              target_size = (picture_size,picture_size),
                                              color_mode = "grayscale",
                                              batch_size=batch_size,
                                              class_mode='categorical',
                                              shuffle=True)


validation_set = datagen_val.flow_from_directory(folder_path+"validation",
                                              target_size = (picture_size,picture_size),
                                              color_mode = "grayscale",
                                              batch_size=batch_size,
                                              class_mode='categorical',
                                              shuffle=False)
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.

# %% [markdown]
# ## Build the Model

# %%
no_of_classes = 7

model = Sequential()

#1st CNN layer
model.add(Conv2D(64,(3,3),padding = 'same',input_shape = (48,48,1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.25))

#2nd CNN layer
model.add(Conv2D(128,(5,5),padding = 'same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout (0.25))

#3rd CNN layer
model.add(Conv2D(512,(3,3),padding = 'same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout (0.25))

#4th CNN layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())

#Fully connected 1st layer
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))


# Fully connected layer 2nd layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(no_of_classes, activation='softmax'))



opt = Adam(learning_rate = 0.0001)
model.compile(optimizer=opt,loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_16 (Conv2D)          (None, 48, 48, 64)        640
#
#  batch_normalization_24 (Bat  (None, 48, 48, 64)       256
#  chNormalization)
#
#  activation_24 (Activation)  (None, 48, 48, 64)        0
#
#  max_pooling2d_16 (MaxPoolin  (None, 24, 24, 64)       0
#  g2D)
#
#  dropout_24 (Dropout)        (None, 24, 24, 64)        0
#
#  conv2d_17 (Conv2D)          (None, 24, 24, 128)       204928
#
#  batch_normalization_25 (Bat  (None, 24, 24, 128)      512
#  chNormalization)
#
#  activation_25 (Activation)  (None, 24, 24, 128)       0
#
#  max_pooling2d_17 (MaxPoolin  (None, 12, 12, 128)      0
#  g2D)
#
#  dropout_25 (Dropout)        (None, 12, 12, 128)       0
#
#  conv2d_18 (Conv2D)          (None, 12, 12, 512)       590336
#
#  batch_normalization_26 (Bat  (None, 12, 12, 512)      2048
#  chNormalization)
#
#  activation_26 (Activation)  (None, 12, 12, 512)       0
#
#  max_pooling2d_18 (MaxPoolin  (None, 6, 6, 512)        0
#  g2D)
#
#  dropout_26 (Dropout)        (None, 6, 6, 512)         0
#
#  conv2d_19 (Conv2D)          (None, 6, 6, 512)         2359808
#
#  batch_normalization_27 (Bat  (None, 6, 6, 512)        2048
#  chNormalization)
#
#  activation_27 (Activation)  (None, 6, 6, 512)         0
#
#  max_pooling2d_19 (MaxPoolin  (None, 3, 3, 512)        0
#  g2D)
#
#  dropout_27 (Dropout)        (None, 3, 3, 512)         0
#
#  flatten_4 (Flatten)         (None, 4608)              0
#
#  dense_12 (Dense)            (None, 256)               1179904
#
#  batch_normalization_28 (Bat  (None, 256)              1024
#  chNormalization)
#
#  activation_28 (Activation)  (None, 256)               0
#
#  dropout_28 (Dropout)        (None, 256)               0
#
#  dense_13 (Dense)            (None, 512)               131584
#
#  batch_normalization_29 (Bat  (None, 512)              2048
#  chNormalization)
#
#  activation_29 (Activation)  (None, 512)               0
#
#  dropout_29 (Dropout)        (None, 512)               0
#
#  dense_14 (Dense)            (None, 7)                 3591
#
# =================================================================
# Total params: 4,478,727
# Trainable params: 4,474,759
# Non-trainable params: 3,968
# _________________________________________________________________

# %% [markdown]
# ## Fit the Model with Training and Validation Data

# %%
checkpoint = ModelCheckpoint("model.h5", monitor='val_acc', verbose=1, save_best_only=True, mode='max')

early_stopping = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=3,
                          verbose=1,
                          restore_best_weights=True
                          )

reduce_learningrate = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=3,
                              verbose=1,
                              min_delta=0.0001)

callbacks_list = [early_stopping,checkpoint,reduce_learningrate]

epochs = 48


model.compile(loss='categorical_crossentropy',
              optimizer = Adam(learning_rate=0.001),
              metrics=['accuracy'])

# %%
history = model.fit(x=train_set,
                                steps_per_epoch=train_set.n//train_set.batch_size,
                                epochs=epochs,
                                validation_data = validation_set,
                                validation_steps = validation_set.n//test_set.batch_size,
                                callbacks=callbacks_list
                                )
# Out:
# Epoch 1/48
# 225/225 [==============================] - ETA: 0s - loss: 1.7755 - accuracy: 0.3156WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 21s 92ms/step - loss: 1.7755 - accuracy: 0.3156 - val_loss: 1.6796 - val_accuracy: 0.3822 - lr: 0.0010
# Epoch 2/48
# 225/225 [==============================] - ETA: 0s - loss: 1.4300 - accuracy: 0.4521WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 21s 91ms/step - loss: 1.4300 - accuracy: 0.4521 - val_loss: 1.3347 - val_accuracy: 0.4916 - lr: 0.0010
# Epoch 3/48
# 225/225 [==============================] - ETA: 0s - loss: 1.2741 - accuracy: 0.5145WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 20s 91ms/step - loss: 1.2741 - accuracy: 0.5145 - val_loss: 1.4263 - val_accuracy: 0.4945 - lr: 0.0010
# Epoch 4/48
# 225/225 [==============================] - ETA: 0s - loss: 1.1868 - accuracy: 0.5453WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 21s 91ms/step - loss: 1.1868 - accuracy: 0.5453 - val_loss: 1.1765 - val_accuracy: 0.5521 - lr: 0.0010
# Epoch 5/48
# 225/225 [==============================] - ETA: 0s - loss: 1.1268 - accuracy: 0.5738WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 20s 91ms/step - loss: 1.1268 - accuracy: 0.5738 - val_loss: 1.3635 - val_accuracy: 0.4844 - lr: 0.0010
# Epoch 6/48
# 225/225 [==============================] - ETA: 0s - loss: 1.0818 - accuracy: 0.5890WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 20s 91ms/step - loss: 1.0818 - accuracy: 0.5890 - val_loss: 1.2628 - val_accuracy: 0.5283 - lr: 0.0010
# Epoch 7/48
# 225/225 [==============================] - ETA: 0s - loss: 1.0392 - accuracy: 0.6061WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 21s 91ms/step - loss: 1.0392 - accuracy: 0.6061 - val_loss: 1.1698 - val_accuracy: 0.5709 - lr: 0.0010
# Epoch 8/48
# 225/225 [==============================] - ETA: 0s - loss: 0.9900 - accuracy: 0.6280WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 20s 91ms/step - loss: 0.9900 - accuracy: 0.6280 - val_loss: 1.1772 - val_accuracy: 0.5551 - lr: 0.0010
# Epoch 9/48
# 225/225 [==============================] - ETA: 0s - loss: 0.9471 - accuracy: 0.6438WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 21s 91ms/step - loss: 0.9471 - accuracy: 0.6438 - val_loss: 1.0903 - val_accuracy: 0.5930 - lr: 0.0010
# Epoch 10/48
# 225/225 [==============================] - ETA: 0s - loss: 0.9040 - accuracy: 0.6601WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 20s 91ms/step - loss: 0.9040 - accuracy: 0.6601 - val_loss: 1.0662 - val_accuracy: 0.5987 - lr: 0.0010
# Epoch 11/48
# 225/225 [==============================] - ETA: 0s - loss: 0.8613 - accuracy: 0.6759WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 20s 91ms/step - loss: 0.8613 - accuracy: 0.6759 - val_loss: 1.0918 - val_accuracy: 0.5932 - lr: 0.0010
# Epoch 12/48
# 225/225 [==============================] - ETA: 0s - loss: 0.8168 - accuracy: 0.6946WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 225/225 [==============================] - 20s 91ms/step - loss: 0.8168 - accuracy: 0.6946 - val_loss: 1.2650 - val_accuracy: 0.5584 - lr: 0.0010
# Epoch 13/48
# 225/225 [==============================] - ETA: 0s - loss: 0.7864 - accuracy: 0.7047Restoring model weights from the end of the best epoch: 10.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 225/225 [==============================] - 20s 91ms/step - loss: 0.7864 - accuracy: 0.7047 - val_loss: 1.2211 - val_accuracy: 0.5607 - lr: 0.0010
# Epoch 13: early stopping

# %%
plt.style.use('dark_background')

plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.show()
